# %%
# Import PyDrive and associated libraries.
# This only needs to be done once in a notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Create & upload a text file.
uploaded = drive.CreateFile({'title': 'Sample file.txt'})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1r9vMo96CjefzgfBXsuNXpfcngJAe8WRe

# %%
# List .txt files in the root.
#
# Search query reference:
# https://developers.google.com/drive/v2/web/search-parameters
listed = drive.ListFile({'q': "title contains '.csv' and 'root' in parents"}).GetList()
for file in listed:
  print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title For-Diwali.csv, id 0B92rjQ5q-kGLdTRySWsyZFVSamc

# %%
# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1mmuh_esxrCmROYN-gbguAzRqwCskt0_t' 
#https://drive.google.com/open?id=1hGgt7bX1bY6xEp_ak3AqaVfPXEGTSZwP
#https://drive.google.com/open?id=1PtWC7anhplC8upoold_a1GjxvO_3bjFR
#https://drive.google.com/open?id=135jaLZsbj20QJa4bSDYAc5kROp27B8Kq
#https://drive.google.com/open?id=1VOM44bKLrierpB-Mpq9AUtjkavygpxOK
#https://drive.google.com/open?id=1mmuh_esxrCmROYN-gbguAzRqwCskt0_t
downloaded = drive.CreateFile({'id': file_id})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))

# %%
downloaded.GetContentFile("superstore1.csv")

# %%
# !ls
# Out:
# adc.json  Diabetes.csv	sample_data  superstore1.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("superstore1.csv")

# %%
df.head()
# Out:
#    Order ID  Order Date  ... Product Base Margin   Ship Date
# 0         3  13-10-2010  ...                0.80  20-10-2010
# 1       293  01-10-2012  ...                0.58  02-10-2012
# 2       293  01-10-2012  ...                0.39  03-10-2012
# 3       483  10-07-2011  ...                0.58  12-07-2011
# 4       515  28-08-2010  ...                0.50  30-08-2010
#
# [5 rows x 18 columns]

# %%
df.Sales.mean()
# Out:
# 1775.8781788308177

# %%
df.groupby("Order Priority").mean()
# Out:
#                     Order ID  ...  Product Base Margin
# Order Priority                ...
# Critical        29779.445896  ...             0.514201
# High            30541.058824  ...             0.513350
# Low             29418.526163  ...             0.515664
# Medium          30724.761496  ...             0.507071
# Not Specified   29356.251794  ...             0.512094
#
# [5 rows x 8 columns]

# %%
# !cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set()

# %%
ax= sns.pairplot(df,diag_kind="hist")

# %%
ax= sns.pairplot(df,diag_kind="hist", hue= "Customer Segment")

# %%
import pdb; pdb.set_trace()
# Out:
# --Call--
# > /usr/local/lib/python3.6/dist-packages/IPython/core/displayhook.py(236)__call__()
# -> def __call__(self, result=None):
#
# Documented commands (type help <topic>):
# ...
# EOF    c          d        h         list      q        rv       undisplay
# a      cl         debug    help      ll        quit     s        unt
# alias  clear      disable  ignore    longlist  r        source   until
# args   commands   display  interact  n         restart  step     up
# b      condition  down     j         next      return   tbreak   w
# break  cont       enable   jump      p         retval   u        whatis
# bt     continue   exit     l         pp        run      unalias  where
#
# Miscellaneous help topics:
# ...
# exec  pdb
